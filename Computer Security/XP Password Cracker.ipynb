# %%
import string
import re
import codecs

try:
    f = codecs.open('system', 'rb', 'cp1252')
except IOError:
    f = codecs.open('system', 'wb', 'cp1252')

# %%
with open('SAM', 'r', encoding='cp1254') as f1:
        lines = f1.read()
        f2 = open('my_output_file.xml', 'w', encoding='utf-8')
        f2.write(lines)
        f2.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-e045c68bb8b5> in <module>
#       1 with open('SAM', 'r', encoding='cp1254') as f1:
# ----> 2         lines = f1.read()
#       3         f2 = open('my_output_file.xml', 'w', encoding='utf-8')
#       4         f2.write(lines)
#       5         f2.close()
#
# ~\Anaconda\envs\mlenv\lib\encodings\cp1254.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 164: character maps to <undefined>
